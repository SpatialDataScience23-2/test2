# %%
import pandas as pd

linkGit="https://github.com/SpatialDataScience23-2/test2/raw/main/data.PC1_.csv"

dataRaee=pd.read_csv(linkGit)

# %%
dataRaee
# Out:
#        Make       Model  Year                Engine.Fuel.Type  Engine.HP  \
# 0       BMW  1 Series M  2011     premium unleaded (required)        335
# 1       BMW    1 Series  2011     premium unleaded (required)        300
# 2       BMW    1 Series  2011     premium unleaded (required)        300
# 3       BMW    1 Series  2011     premium unleaded (required)        230
# 4       BMW    1 Series  2011     premium unleaded (required)        230
# ...     ...         ...   ...                             ...        ...
# 8111  Acura         ZDX  2011     premium unleaded (required)        300
# 8112  Acura         ZDX  2012     premium unleaded (required)        300
# 8113  Acura         ZDX  2012     premium unleaded (required)        300
# 8114  Acura         ZDX  2012     premium unleaded (required)        300
# 8115  Acura         ZDX  2013  premium unleaded (recommended)        300
#
#       Engine.Cylinders Transmission.Type     Driven_Wheels  Number.of.Doors  \
# ...
